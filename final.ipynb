# %% [markdown]
# # Final Project
# Generates everything for my final project, excluding SVM and its results which are naturally in and from `svm.ipynb`

# %%
import numpy as np
import cv2 as cv
from algos import *
from write import *
import matplotlib.pyplot as plt
from multiprocessing import pool

# %%
options = {}

# %%
# Reroute
def rer(f, *args):
    return lambda img: f(img, *args)

# %% [markdown]
# ## Project Data

# %%
hrleaf = get_img("orig/healthy-rust-leaf.jpg")
hsleaf = get_img("orig/healthy-scab-leaf.jpg")
sleaf = get_img("orig/sick-leaf.jpg")
multi_show([hrleaf, hsleaf, sleaf]) # matplotlib assumes rgb not bgr here

# %% [markdown]
# ## Enhancement

# %%
multi_save(
    "final",
    [("hrleaf", hrleaf)],
    [
        ("med_blur", cv.medianBlur),
    ],
    [
        (3, "k"),
    ],
)
